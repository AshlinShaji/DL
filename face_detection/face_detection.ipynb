# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread('rajani.jpeg')
img
# Out:
# array([[[153, 154,   0],
#         [153, 154,   0],
#         [153, 154,   0],
#         ...,
#         [157, 158,   0],
#         [157, 158,   0],
#         [157, 158,   0]],
#
#        [[154, 155,   0],
#         [154, 155,   0],
#         [154, 155,   0],
#         ...,
#         [158, 159,   1],
#         [158, 159,   1],
#         [158, 159,   1]],
#
#        [[155, 156,   0],
#         [155, 156,   0],
#         [155, 156,   0],
#         ...,
#         [159, 161,   1],
#         [159, 161,   1],
#         [159, 161,   1]],
#
#        ...,
#
#        [[ 80,  35,   1],
#         [ 80,  36,   0],
#         [ 77,  35,   0],
#         ...,
#         [ 74,  36,   2],
#         [ 73,  34,   2],
#         [ 73,  35,   1]],
#
#        [[ 86,  41,   4],
#         [ 86,  41,   3],
#         [ 85,  40,   3],
#         ...,
#         [ 79,  39,   4],
#         [ 79,  38,   5],
#         [ 79,  39,   4]],
#
#        [[ 92,  45,   7],
#         [ 92,  45,   7],
#         [ 92,  45,   7],
# ...

# %%
plt.imshow(img)

# %%
conv_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(conv_img)

# %%
face_data=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
face_data
# Out:
# < cv2.CascadeClassifier 000001B2AE68BD50>

# %%
#face detect
faces=face_data.detectMultiScale(conv_img)
faces
# Out:
# array([[ 45,  58,  28,  28],
#        [127,  65,  27,  27]], dtype=int32)

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(conv_img,(x,y),(x+w,y+h),(255,0,0),2)

# %%
plt.imshow(conv_img)

# %%
img1=cv2.imread('group.jpg')
img1
# Out:
# array([[[221, 225, 220],
#         [221, 225, 220],
#         [221, 225, 220],
#         ...,
#         [214, 218, 213],
#         [214, 218, 213],
#         [213, 217, 211]],
#
#        [[221, 225, 220],
#         [221, 225, 220],
#         [221, 225, 220],
#         ...,
#         [214, 218, 213],
#         [214, 218, 213],
#         [214, 218, 212]],
#
#        [[221, 225, 220],
#         [221, 225, 220],
#         [221, 225, 220],
#         ...,
#         [214, 218, 213],
#         [214, 218, 213],
#         [214, 218, 212]],
#
#        ...,
#
#        [[ 12,  38,  14],
#         [  0,  20,   0],
#         [115, 129, 105],
#         ...,
#         [  3,  58,  33],
#         [  0,  58,  34],
#         [  1,  54,  27]],
#
#        [[ 23,  49,  25],
#         [  0,  21,   0],
#         [ 91, 105,  81],
#         ...,
#         [  3,  57,  34],
#         [  0,  53,  29],
#         [  1,  56,  31]],
#
#        [[ 19,  43,  19],
#         [  0,  16,   0],
#         [ 75,  89,  65],
# ...

# %%
plt.imshow(img1)

# %%
conv_img1=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
plt.imshow(conv_img1)

# %%
faces=face_data.detectMultiScale(conv_img1)
faces
# Out:
# array([[165,  39,  55,  55],
#        [361,  64,  57,  57],
#        [440,  46,  53,  53],
#        [316, 118,  61,  61],
#        [235,  59,  56,  56],
#        [ 92,  88,  93,  93],
#        [ 62,  23,  59,  59]], dtype=int32)

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(conv_img1,(x,y),(x+w,y+h),(255,0,0),2)

# %%
plt.imshow(conv_img1)
