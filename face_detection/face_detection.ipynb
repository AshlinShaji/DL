# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread('nivin.jpg')
img
# Out:
# array([[[ 34,  33,  75],
#         [ 30,  30,  70],
#         [ 24,  24,  64],
#         ...,
#         [  3,  22,  79],
#         [  2,  22,  80],
#         [  0,  21,  82]],
#
#        [[ 27,  26,  68],
#         [ 23,  23,  63],
#         [ 18,  19,  57],
#         ...,
#         [  4,  23,  80],
#         [  3,  23,  81],
#         [  3,  22,  83]],
#
#        [[ 16,  16,  56],
#         [ 13,  13,  53],
#         [  9,  10,  48],
#         ...,
#         [  4,  24,  79],
#         [  3,  23,  80],
#         [  3,  23,  81]],
#
#        ...,
#
#        [[  2,  34,  75],
#         [  3,  35,  76],
#         [  6,  36,  77],
#         ...,
#         [ 17,  49, 115],
#         [ 16,  48, 113],
#         [ 16,  48, 113]],
#
#        [[  3,  35,  78],
#         [  4,  36,  79],
#         [  6,  35,  79],
#         ...,
#         [ 15,  49, 115],
#         [ 14,  48, 114],
#         [ 13,  47, 113]],
#
#        [[  3,  35,  78],
#         [  4,  36,  79],
#         [  7,  36,  80],
# ...

# %%
plt.imshow(img)

# %%
conv_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(conv_img)
