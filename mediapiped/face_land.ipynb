# %%
import mediapipe as mp
import cv2

# %%
mp_detection=mp.solutions.face_detection
mp_drawing=mp.solutions.drawing_utils

# %%
face_detect=mp_detection.FaceDetection()

# %%
video=cv2.VideoCapture(0)
while True:
    suc,img=video.read()
    img1=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    result=face_detect.process(img1)
    print(result.detections)
    
    if result.detections:
        for x in result.detections:
            mp_drawing.draw_detection(img,x)


    cv2.imshow('Face Landmarks', img)
    if cv2.waitKey(1) & 0xFF==ord('q'):
        break

video.release() 
cv2.destroyAllWindows()
# Out:
# [label_id: 0
# score: 0.9463902115821838
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5006580352783203
#     ymin: 0.21259118616580963
#     width: 0.2792441248893738
#     height: 0.37231630086898804
#   }
#   relative_keypoints {
#     x: 0.6077227592468262
#     y: 0.31483757495880127
#   }
#   relative_keypoints {
#     x: 0.7192642092704773
#     y: 0.3308848738670349
#   }
#   relative_keypoints {
#     x: 0.6737536787986755
#     y: 0.41936367750167847
#   }
#   relative_keypoints {
#     x: 0.6614626049995422
#     y: 0.4876914620399475
#   }
#   relative_keypoints {
#     x: 0.5167554616928101
#     y: 0.3287157416343689
#   }
#   relative_keypoints {
#     x: 0.7553750872612
#     y: 0.35971343517303467
#   }
# }
# ]
# [label_id: 0
# score: 0.9456859827041626
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5044010281562805
#     ymin: 0.21400101482868195
#     width: 0.27802860736846924
#     height: 0.3706967234611511
#   }
#   relative_keypoints {
#     x: 0.6056926846504211
#     y: 0.31409281492233276
#   }
#   relative_keypoints {
#     x: 0.7205713391304016
#     y: 0.3354104161262512
#   }
#   relative_keypoints {
#     x: 0.6687231659889221
#     y: 0.4213675856590271
#   }
#   relative_keypoints {
#     x: 0.6563803553581238
#     y: 0.48922377824783325
#   }
#   relative_keypoints {
#     x: 0.5175806283950806
#     y: 0.3236095905303955
#   }
#   relative_keypoints {
#     x: 0.7619637846946716
#     y: 0.36450737714767456
#   }
# }
# ]
# [label_id: 0
# score: 0.9456859827041626
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5044010281562805
#     ymin: 0.21400101482868195
#     width: 0.27802860736846924
#     height: 0.3706967234611511
#   }
#   relative_keypoints {
#     x: 0.6056926846504211
#     y: 0.31409281492233276
#   }
#   relative_keypoints {
#     x: 0.7205713391304016
#     y: 0.3354104161262512
#   }
#   relative_keypoints {
#     x: 0.6687231659889221
#     y: 0.4213675856590271
#   }
#   relative_keypoints {
#     x: 0.6563803553581238
#     y: 0.48922377824783325
#   }
#   relative_keypoints {
#     x: 0.5175806283950806
#     y: 0.3236095905303955
#   }
#   relative_keypoints {
#     x: 0.7619637846946716
#     y: 0.36450737714767456
#   }
# }
# ]
# [label_id: 0
# score: 0.9481645226478577
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5084800720214844
#     ymin: 0.21519573032855988
#     width: 0.2760750651359558
#     height: 0.3680921792984009
#   }
#   relative_keypoints {
#     x: 0.604224681854248
#     y: 0.3161551356315613
#   }
#   relative_keypoints {
#     x: 0.7181527018547058
#     y: 0.3333999514579773
#   }
#   relative_keypoints {
#     x: 0.6646976470947266
#     y: 0.4205843210220337
#   }
#   relative_keypoints {
#     x: 0.655264675617218
#     y: 0.4881327748298645
#   }
#   relative_keypoints {
#     x: 0.5230247974395752
#     y: 0.3281174898147583
#   }
#   relative_keypoints {
#     x: 0.7655734419822693
#     y: 0.3609870672225952
#   }
# }
# ]
# [label_id: 0
# score: 0.9448379874229431
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5014492273330688
#     ymin: 0.2140994817018509
#     width: 0.2812000513076782
#     height: 0.3749241232872009
#   }
#   relative_keypoints {
#     x: 0.6042270660400391
#     y: 0.31819701194763184
#   }
#   relative_keypoints {
#     x: 0.7176697254180908
#     y: 0.3329169750213623
#   }
#   relative_keypoints {
#     x: 0.6687749624252319
#     y: 0.42368602752685547
#   }
#   relative_keypoints {
#     x: 0.6582615375518799
#     y: 0.49194544553756714
#   }
#   relative_keypoints {
#     x: 0.5174242258071899
#     y: 0.33087438344955444
#   }
#   relative_keypoints {
#     x: 0.7599590420722961
#     y: 0.3595861792564392
#   }
# }
# ]
# [label_id: 0
# score: 0.9448379874229431
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5014492273330688
#     ymin: 0.2140994817018509
#     width: 0.2812000513076782
#     height: 0.3749241232872009
#   }
#   relative_keypoints {
#     x: 0.6042270660400391
#     y: 0.31819701194763184
#   }
#   relative_keypoints {
#     x: 0.7176697254180908
#     y: 0.3329169750213623
#   }
#   relative_keypoints {
#     x: 0.6687749624252319
#     y: 0.42368602752685547
#   }
#   relative_keypoints {
#     x: 0.6582615375518799
#     y: 0.49194544553756714
#   }
#   relative_keypoints {
#     x: 0.5174242258071899
#     y: 0.33087438344955444
#   }
#   relative_keypoints {
#     x: 0.7599590420722961
#     y: 0.3595861792564392
#   }
# }
# ]
# [label_id: 0
# score: 0.9467952847480774
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5055590271949768
#     ymin: 0.2084776908159256
#     width: 0.28227514028549194
#     height: 0.3763580918312073
#   }
#   relative_keypoints {
#     x: 0.6054487228393555
#     y: 0.3149508833885193
#   }
#   relative_keypoints {
#     x: 0.7195492386817932
#     y: 0.3351222276687622
#   }
#   relative_keypoints {
#     x: 0.6655746102333069
#     y: 0.42754775285720825
#   }
#   relative_keypoints {
#     x: 0.6545323133468628
#     y: 0.49227726459503174
#   }
#   relative_keypoints {
#     x: 0.5228200554847717
#     y: 0.3171411156654358
#   }
#   relative_keypoints {
#     x: 0.7655688524246216
#     y: 0.3567999601364136
#   }
# }
# ]
# [label_id: 0
# score: 0.9467952847480774
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5055590271949768
#     ymin: 0.2084776908159256
#     width: 0.28227514028549194
#     height: 0.3763580918312073
#   }
#   relative_keypoints {
#     x: 0.6054487228393555
#     y: 0.3149508833885193
#   }
#   relative_keypoints {
#     x: 0.7195492386817932
#     y: 0.3351222276687622
#   }
#   relative_keypoints {
#     x: 0.6655746102333069
#     y: 0.42754775285720825
#   }
#   relative_keypoints {
#     x: 0.6545323133468628
#     y: 0.49227726459503174
#   }
#   relative_keypoints {
#     x: 0.5228200554847717
#     y: 0.3171411156654358
#   }
#   relative_keypoints {
#     x: 0.7655688524246216
#     y: 0.3567999601364136
#   }
# }
# ]
# [label_id: 0
# score: 0.9342607855796814
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5053433775901794
#     ymin: 0.2162877470254898
#     width: 0.27925407886505127
#     height: 0.37232959270477295
#   }
#   relative_keypoints {
#     x: 0.6100630760192871
#     y: 0.3197088837623596
#   }
#   relative_keypoints {
#     x: 0.7228334546089172
#     y: 0.34082114696502686
#   }
#   relative_keypoints {
#     x: 0.6727641224861145
#     y: 0.4301881194114685
#   }
#   relative_keypoints {
#     x: 0.6592080593109131
#     y: 0.49656015634536743
#   }
#   relative_keypoints {
#     x: 0.5203866362571716
#     y: 0.3235652446746826
#   }
#   relative_keypoints {
#     x: 0.76136314868927
#     y: 0.365419864654541
#   }
# }
# ]
# [label_id: 0
# score: 0.9342607855796814
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5053433775901794
#     ymin: 0.2162877470254898
#     width: 0.27925407886505127
#     height: 0.37232959270477295
#   }
#   relative_keypoints {
#     x: 0.6100630760192871
#     y: 0.3197088837623596
#   }
#   relative_keypoints {
#     x: 0.7228334546089172
#     y: 0.34082114696502686
#   }
#   relative_keypoints {
#     x: 0.6727641224861145
#     y: 0.4301881194114685
#   }
#   relative_keypoints {
#     x: 0.6592080593109131
#     y: 0.49656015634536743
#   }
#   relative_keypoints {
#     x: 0.5203866362571716
#     y: 0.3235652446746826
#   }
#   relative_keypoints {
#     x: 0.76136314868927
#     y: 0.365419864654541
#   }
# }
# ]
# [label_id: 0
# score: 0.9515988230705261
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.502232551574707
#     ymin: 0.21238084137439728
#     width: 0.28091228008270264
#     height: 0.3745418190956116
#   }
#   relative_keypoints {
#     x: 0.6048017740249634
#     y: 0.3171338438987732
#   }
#   relative_keypoints {
#     x: 0.7186135649681091
#     y: 0.33472055196762085
#   }
#   relative_keypoints {
#     x: 0.6681423783302307
#     y: 0.425620973110199
#   }
#   relative_keypoints {
#     x: 0.6570332646369934
#     y: 0.4918496012687683
#   }
#   relative_keypoints {
#     x: 0.5184141993522644
#     y: 0.32523149251937866
#   }
#   relative_keypoints {
#     x: 0.7609934210777283
#     y: 0.35906416177749634
#   }
# }
# ]
# [label_id: 0
# score: 0.9515988230705261
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.502232551574707
#     ymin: 0.21238084137439728
#     width: 0.28091228008270264
#     height: 0.3745418190956116
#   }
#   relative_keypoints {
#     x: 0.6048017740249634
#     y: 0.3171338438987732
#   }
#   relative_keypoints {
#     x: 0.7186135649681091
#     y: 0.33472055196762085
#   }
#   relative_keypoints {
#     x: 0.6681423783302307
#     y: 0.425620973110199
#   }
#   relative_keypoints {
#     x: 0.6570332646369934
#     y: 0.4918496012687683
#   }
#   relative_keypoints {
#     x: 0.5184141993522644
#     y: 0.32523149251937866
#   }
#   relative_keypoints {
#     x: 0.7609934210777283
#     y: 0.35906416177749634
#   }
# }
# ]
# [label_id: 0
# score: 0.9547303915023804
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5002833008766174
#     ymin: 0.20862369239330292
#     width: 0.2873052954673767
#     height: 0.3830644488334656
#   }
#   relative_keypoints {
#     x: 0.6025617718696594
#     y: 0.318509578704834
#   }
#   relative_keypoints {
#     x: 0.7165209650993347
#     y: 0.3355602025985718
#   }
#   relative_keypoints {
#     x: 0.6637783050537109
#     y: 0.4317627549171448
#   }
#   relative_keypoints {
#     x: 0.6539228558540344
#     y: 0.49685508012771606
#   }
#   relative_keypoints {
#     x: 0.5204561352729797
#     y: 0.3231039047241211
#   }
#   relative_keypoints {
#     x: 0.7636445164680481
#     y: 0.3565290570259094
#   }
# }
# ]
# [label_id: 0
# score: 0.9440774917602539
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.506147563457489
#     ymin: 0.21618129312992096
#     width: 0.2793726921081543
#     height: 0.37248820066452026
#   }
#   relative_keypoints {
#     x: 0.614159107208252
#     y: 0.319551944732666
#   }
#   relative_keypoints {
#     x: 0.7247098088264465
#     y: 0.3461850881576538
#   }
#   relative_keypoints {
#     x: 0.674568235874176
#     y: 0.43549805879592896
#   }
#   relative_keypoints {
#     x: 0.6589909195899963
#     y: 0.49870961904525757
#   }
#   relative_keypoints {
#     x: 0.5232692956924438
#     y: 0.31526756286621094
#   }
#   relative_keypoints {
#     x: 0.760418176651001
#     y: 0.36802107095718384
#   }
# }
# ]
# [label_id: 0
# score: 0.9440774917602539
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.506147563457489
#     ymin: 0.21618129312992096
#     width: 0.2793726921081543
#     height: 0.37248820066452026
#   }
#   relative_keypoints {
#     x: 0.614159107208252
#     y: 0.319551944732666
#   }
#   relative_keypoints {
#     x: 0.7247098088264465
#     y: 0.3461850881576538
#   }
#   relative_keypoints {
#     x: 0.674568235874176
#     y: 0.43549805879592896
#   }
#   relative_keypoints {
#     x: 0.6589909195899963
#     y: 0.49870961904525757
#   }
#   relative_keypoints {
#     x: 0.5232692956924438
#     y: 0.31526756286621094
#   }
#   relative_keypoints {
#     x: 0.760418176651001
#     y: 0.36802107095718384
#   }
# }
# ]
# [label_id: 0
# score: 0.9415475726127625
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5077672600746155
#     ymin: 0.21880464255809784
#     width: 0.2778722643852234
#     height: 0.3704873323440552
#   }
#   relative_keypoints {
#     x: 0.6113743185997009
#     y: 0.32264822721481323
#   }
#   relative_keypoints {
#     x: 0.7240523099899292
#     y: 0.344035804271698
#   }
#   relative_keypoints {
#     x: 0.6737543344497681
#     y: 0.4341173768043518
#   }
#   relative_keypoints {
#     x: 0.6611098051071167
#     y: 0.4983266592025757
#   }
#   relative_keypoints {
#     x: 0.523271918296814
#     y: 0.32536113262176514
#   }
#   relative_keypoints {
#     x: 0.7633358240127563
#     y: 0.366743266582489
#   }
# }
# ]
# [label_id: 0
# score: 0.9415475726127625
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5077672600746155
#     ymin: 0.21880464255809784
#     width: 0.2778722643852234
#     height: 0.3704873323440552
#   }
#   relative_keypoints {
#     x: 0.6113743185997009
#     y: 0.32264822721481323
#   }
#   relative_keypoints {
#     x: 0.7240523099899292
#     y: 0.344035804271698
#   }
#   relative_keypoints {
#     x: 0.6737543344497681
#     y: 0.4341173768043518
#   }
#   relative_keypoints {
#     x: 0.6611098051071167
#     y: 0.4983266592025757
#   }
#   relative_keypoints {
#     x: 0.523271918296814
#     y: 0.32536113262176514
#   }
#   relative_keypoints {
#     x: 0.7633358240127563
#     y: 0.366743266582489
#   }
# }
# ]
# [label_id: 0
# score: 0.9460739493370056
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5031813979148865
#     ymin: 0.21636800467967987
#     width: 0.2826206684112549
#     height: 0.3768179416656494
#   }
#   relative_keypoints {
#     x: 0.6136313676834106
#     y: 0.3235214948654175
#   }
#   relative_keypoints {
#     x: 0.7252598404884338
#     y: 0.33831435441970825
#   }
#   relative_keypoints {
#     x: 0.6814306378364563
#     y: 0.43237918615341187
#   }
#   relative_keypoints {
#     x: 0.6691778898239136
#     y: 0.49859392642974854
#   }
#   relative_keypoints {
#     x: 0.5211195349693298
#     y: 0.3320748209953308
#   }
#   relative_keypoints {
#     x: 0.7599084973335266
#     y: 0.36044973134994507
#   }
# }
# ]
# [label_id: 0
# score: 0.9460739493370056
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5031813979148865
#     ymin: 0.21636800467967987
#     width: 0.2826206684112549
#     height: 0.3768179416656494
#   }
#   relative_keypoints {
#     x: 0.6136313676834106
#     y: 0.3235214948654175
#   }
#   relative_keypoints {
#     x: 0.7252598404884338
#     y: 0.33831435441970825
#   }
#   relative_keypoints {
#     x: 0.6814306378364563
#     y: 0.43237918615341187
#   }
#   relative_keypoints {
#     x: 0.6691778898239136
#     y: 0.49859392642974854
#   }
#   relative_keypoints {
#     x: 0.5211195349693298
#     y: 0.3320748209953308
#   }
#   relative_keypoints {
#     x: 0.7599084973335266
#     y: 0.36044973134994507
#   }
# }
# ]
# [label_id: 0
# score: 0.953058660030365
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5048946142196655
#     ymin: 0.21173621714115143
#     width: 0.2851039171218872
#     height: 0.38012951612472534
#   }
#   relative_keypoints {
#     x: 0.6095861196517944
#     y: 0.31994879245758057
#   }
#   relative_keypoints {
#     x: 0.7243370413780212
#     y: 0.33751457929611206
#   }
#   relative_keypoints {
#     x: 0.6733558773994446
#     y: 0.43257296085357666
#   }
#   relative_keypoints {
#     x: 0.6618505716323853
#     y: 0.497752845287323
#   }
#   relative_keypoints {
#     x: 0.5223135352134705
#     y: 0.32439422607421875
#   }
#   relative_keypoints {
#     x: 0.7666913866996765
#     y: 0.35946422815322876
#   }
# }
# ]
# [label_id: 0
# score: 0.953058660030365
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5048946142196655
#     ymin: 0.21173621714115143
#     width: 0.2851039171218872
#     height: 0.38012951612472534
#   }
#   relative_keypoints {
#     x: 0.6095861196517944
#     y: 0.31994879245758057
#   }
#   relative_keypoints {
#     x: 0.7243370413780212
#     y: 0.33751457929611206
#   }
#   relative_keypoints {
#     x: 0.6733558773994446
#     y: 0.43257296085357666
#   }
#   relative_keypoints {
#     x: 0.6618505716323853
#     y: 0.497752845287323
#   }
#   relative_keypoints {
#     x: 0.5223135352134705
#     y: 0.32439422607421875
#   }
#   relative_keypoints {
#     x: 0.7666913866996765
#     y: 0.35946422815322876
#   }
# }
# ]
# [label_id: 0
# score: 0.9447984099388123
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5043267607688904
#     ymin: 0.2116061896085739
#     width: 0.28275179862976074
#     height: 0.37699300050735474
#   }
#   relative_keypoints {
#     x: 0.6091973781585693
#     y: 0.3172788619995117
#   }
#   relative_keypoints {
#     x: 0.7237487435340881
#     y: 0.3323823809623718
#   }
#   relative_keypoints {
#     x: 0.6753407716751099
#     y: 0.4248535633087158
#   }
#   relative_keypoints {
#     x: 0.6639525890350342
#     y: 0.49245506525039673
#   }
#   relative_keypoints {
#     x: 0.5202276110649109
#     y: 0.3274220824241638
#   }
#   relative_keypoints {
#     x: 0.7642056941986084
#     y: 0.3569261431694031
#   }
# }
# ]
# [label_id: 0
# score: 0.9447984099388123
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5043267607688904
#     ymin: 0.2116061896085739
#     width: 0.28275179862976074
#     height: 0.37699300050735474
#   }
#   relative_keypoints {
#     x: 0.6091973781585693
#     y: 0.3172788619995117
#   }
#   relative_keypoints {
#     x: 0.7237487435340881
#     y: 0.3323823809623718
#   }
#   relative_keypoints {
#     x: 0.6753407716751099
#     y: 0.4248535633087158
#   }
#   relative_keypoints {
#     x: 0.6639525890350342
#     y: 0.49245506525039673
#   }
#   relative_keypoints {
#     x: 0.5202276110649109
#     y: 0.3274220824241638
#   }
#   relative_keypoints {
#     x: 0.7642056941986084
#     y: 0.3569261431694031
#   }
# }
# ]
# [label_id: 0
# score: 0.9481714963912964
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5033831596374512
#     ymin: 0.207199826836586
#     width: 0.28902506828308105
#     height: 0.38535696268081665
#   }
#   relative_keypoints {
#     x: 0.6074131727218628
#     y: 0.3186243772506714
#   }
#   relative_keypoints {
#     x: 0.7235652208328247
#     y: 0.3314743638038635
#   }
#   relative_keypoints {
#     x: 0.6734095215797424
#     y: 0.4294285178184509
#   }
#   relative_keypoints {
#     x: 0.6638981103897095
#     y: 0.49611055850982666
#   }
#   relative_keypoints {
#     x: 0.5220250487327576
#     y: 0.32720810174942017
#   }
#   relative_keypoints {
#     x: 0.7689114212989807
#     y: 0.3524196743965149
#   }
# }
# ]
# [label_id: 0
# score: 0.9481714963912964
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5033831596374512
#     ymin: 0.207199826836586
#     width: 0.28902506828308105
#     height: 0.38535696268081665
#   }
#   relative_keypoints {
#     x: 0.6074131727218628
#     y: 0.3186243772506714
#   }
#   relative_keypoints {
#     x: 0.7235652208328247
#     y: 0.3314743638038635
#   }
#   relative_keypoints {
#     x: 0.6734095215797424
#     y: 0.4294285178184509
#   }
#   relative_keypoints {
#     x: 0.6638981103897095
#     y: 0.49611055850982666
#   }
#   relative_keypoints {
#     x: 0.5220250487327576
#     y: 0.32720810174942017
#   }
#   relative_keypoints {
#     x: 0.7689114212989807
#     y: 0.3524196743965149
#   }
# }
# ]
# [label_id: 0
# score: 0.9366194009780884
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5085631012916565
#     ymin: 0.21374960243701935
#     width: 0.28182387351989746
#     height: 0.3757563829421997
#   }
#   relative_keypoints {
#     x: 0.6086689233779907
#     y: 0.3150952458381653
#   }
#   relative_keypoints {
#     x: 0.7241042256355286
#     y: 0.33373475074768066
#   }
#   relative_keypoints {
#     x: 0.6709607243537903
#     y: 0.42125970125198364
#   }
#   relative_keypoints {
#     x: 0.6600269079208374
#     y: 0.4907152056694031
#   }
#   relative_keypoints {
#     x: 0.5239701867103577
#     y: 0.32731419801712036
#   }
#   relative_keypoints {
#     x: 0.769938588142395
#     y: 0.36379581689834595
#   }
# }
# ]
# [label_id: 0
# score: 0.9380808472633362
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5091553330421448
#     ymin: 0.21015752851963043
#     width: 0.2834583520889282
#     height: 0.3779352903366089
#   }
#   relative_keypoints {
#     x: 0.611319363117218
#     y: 0.3113216161727905
#   }
#   relative_keypoints {
#     x: 0.7275169491767883
#     y: 0.33005625009536743
#   }
#   relative_keypoints {
#     x: 0.674282968044281
#     y: 0.41741281747817993
#   }
#   relative_keypoints {
#     x: 0.6626206040382385
#     y: 0.4884795546531677
#   }
#   relative_keypoints {
#     x: 0.5244946479797363
#     y: 0.3253902792930603
#   }
#   relative_keypoints {
#     x: 0.7715413570404053
#     y: 0.3628639578819275
#   }
# }
# ]
# [label_id: 0
# score: 0.9380808472633362
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5091553330421448
#     ymin: 0.21015752851963043
#     width: 0.2834583520889282
#     height: 0.3779352903366089
#   }
#   relative_keypoints {
#     x: 0.611319363117218
#     y: 0.3113216161727905
#   }
#   relative_keypoints {
#     x: 0.7275169491767883
#     y: 0.33005625009536743
#   }
#   relative_keypoints {
#     x: 0.674282968044281
#     y: 0.41741281747817993
#   }
#   relative_keypoints {
#     x: 0.6626206040382385
#     y: 0.4884795546531677
#   }
#   relative_keypoints {
#     x: 0.5244946479797363
#     y: 0.3253902792930603
#   }
#   relative_keypoints {
#     x: 0.7715413570404053
#     y: 0.3628639578819275
#   }
# }
# ]
# [label_id: 0
# score: 0.9462674260139465
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5071659684181213
#     ymin: 0.21067596971988678
#     width: 0.28228944540023804
#     height: 0.3763768672943115
#   }
#   relative_keypoints {
#     x: 0.6130972504615784
#     y: 0.31769102811813354
#   }
#   relative_keypoints {
#     x: 0.7252566814422607
#     y: 0.3388493061065674
#   }
#   relative_keypoints {
#     x: 0.6747770309448242
#     y: 0.43204766511917114
#   }
#   relative_keypoints {
#     x: 0.6615731716156006
#     y: 0.4957578182220459
#   }
#   relative_keypoints {
#     x: 0.5253216028213501
#     y: 0.316677451133728
#   }
#   relative_keypoints {
#     x: 0.7651799321174622
#     y: 0.35861891508102417
#   }
# }
# ]
# [label_id: 0
# score: 0.9462674260139465
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5071659684181213
#     ymin: 0.21067596971988678
#     width: 0.28228944540023804
#     height: 0.3763768672943115
#   }
#   relative_keypoints {
#     x: 0.6130972504615784
#     y: 0.31769102811813354
#   }
#   relative_keypoints {
#     x: 0.7252566814422607
#     y: 0.3388493061065674
#   }
#   relative_keypoints {
#     x: 0.6747770309448242
#     y: 0.43204766511917114
#   }
#   relative_keypoints {
#     x: 0.6615731716156006
#     y: 0.4957578182220459
#   }
#   relative_keypoints {
#     x: 0.5253216028213501
#     y: 0.316677451133728
#   }
#   relative_keypoints {
#     x: 0.7651799321174622
#     y: 0.35861891508102417
#   }
# }
# ]
# [label_id: 0
# score: 0.9522658586502075
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5085613131523132
#     ymin: 0.21420414745807648
#     width: 0.2863447070121765
#     height: 0.3817841410636902
#   }
#   relative_keypoints {
#     x: 0.6087468862533569
#     y: 0.3211783766746521
#   }
#   relative_keypoints {
#     x: 0.724658191204071
#     y: 0.33781760931015015
#   }
#   relative_keypoints {
#     x: 0.66977459192276
#     y: 0.4310072660446167
#   }
#   relative_keypoints {
#     x: 0.6597861647605896
#     y: 0.49810725450515747
#   }
#   relative_keypoints {
#     x: 0.5268194675445557
#     y: 0.3295520544052124
#   }
#   relative_keypoints {
#     x: 0.7732682824134827
#     y: 0.3637670874595642
#   }
# }
# ]
# [label_id: 0
# score: 0.9522658586502075
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5085613131523132
#     ymin: 0.21420414745807648
#     width: 0.2863447070121765
#     height: 0.3817841410636902
#   }
#   relative_keypoints {
#     x: 0.6087468862533569
#     y: 0.3211783766746521
#   }
#   relative_keypoints {
#     x: 0.724658191204071
#     y: 0.33781760931015015
#   }
#   relative_keypoints {
#     x: 0.66977459192276
#     y: 0.4310072660446167
#   }
#   relative_keypoints {
#     x: 0.6597861647605896
#     y: 0.49810725450515747
#   }
#   relative_keypoints {
#     x: 0.5268194675445557
#     y: 0.3295520544052124
#   }
#   relative_keypoints {
#     x: 0.7732682824134827
#     y: 0.3637670874595642
#   }
# }
# ]
# [label_id: 0
# score: 0.9499729871749878
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5085044503211975
#     ymin: 0.2032753974199295
#     width: 0.28815901279449463
#     height: 0.3842027187347412
#   }
#   relative_keypoints {
#     x: 0.6096457242965698
#     y: 0.3120937943458557
#   }
#   relative_keypoints {
#     x: 0.7270693778991699
#     y: 0.33411508798599243
#   }
#   relative_keypoints {
#     x: 0.6699998378753662
#     y: 0.42878443002700806
#   }
#   relative_keypoints {
#     x: 0.6582173705101013
#     y: 0.49395281076431274
#   }
#   relative_keypoints {
#     x: 0.5260021686553955
#     y: 0.31145167350769043
#   }
#   relative_keypoints {
#     x: 0.7750933170318604
#     y: 0.35600823163986206
#   }
# }
# ]
# [label_id: 0
# score: 0.9358648657798767
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5099349617958069
#     ymin: 0.2054011970758438
#     width: 0.28659290075302124
#     height: 0.3821137547492981
#   }
#   relative_keypoints {
#     x: 0.6097016930580139
#     y: 0.31000131368637085
#   }
#   relative_keypoints {
#     x: 0.7269472479820251
#     y: 0.33268028497695923
#   }
#   relative_keypoints {
#     x: 0.6689972281455994
#     y: 0.42316967248916626
#   }
#   relative_keypoints {
#     x: 0.6576573252677917
#     y: 0.491585910320282
#   }
#   relative_keypoints {
#     x: 0.5273454785346985
#     y: 0.3155215382575989
#   }
#   relative_keypoints {
#     x: 0.7754620313644409
#     y: 0.3601797819137573
#   }
# }
# ]
# [label_id: 0
# score: 0.9358648657798767
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5099349617958069
#     ymin: 0.2054011970758438
#     width: 0.28659290075302124
#     height: 0.3821137547492981
#   }
#   relative_keypoints {
#     x: 0.6097016930580139
#     y: 0.31000131368637085
#   }
#   relative_keypoints {
#     x: 0.7269472479820251
#     y: 0.33268028497695923
#   }
#   relative_keypoints {
#     x: 0.6689972281455994
#     y: 0.42316967248916626
#   }
#   relative_keypoints {
#     x: 0.6576573252677917
#     y: 0.491585910320282
#   }
#   relative_keypoints {
#     x: 0.5273454785346985
#     y: 0.3155215382575989
#   }
#   relative_keypoints {
#     x: 0.7754620313644409
#     y: 0.3601797819137573
#   }
# }
# ]
# [label_id: 0
# score: 0.9327521920204163
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5181262493133545
#     ymin: 0.22214443981647491
#     width: 0.27571791410446167
#     height: 0.3676156997680664
#   }
#   relative_keypoints {
#     x: 0.6129845380783081
#     y: 0.31614696979522705
#   }
#   relative_keypoints {
#     x: 0.7297415137290955
#     y: 0.33738601207733154
#   }
#   relative_keypoints {
#     x: 0.6741744875907898
#     y: 0.4177781939506531
#   }
#   relative_keypoints {
#     x: 0.6634859442710876
#     y: 0.48926520347595215
#   }
#   relative_keypoints {
#     x: 0.5296399593353271
#     y: 0.3333844542503357
#   }
#   relative_keypoints {
#     x: 0.7770136594772339
#     y: 0.37418389320373535
#   }
# }
# ]
# [label_id: 0
# score: 0.9327521920204163
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5181262493133545
#     ymin: 0.22214443981647491
#     width: 0.27571791410446167
#     height: 0.3676156997680664
#   }
#   relative_keypoints {
#     x: 0.6129845380783081
#     y: 0.31614696979522705
#   }
#   relative_keypoints {
#     x: 0.7297415137290955
#     y: 0.33738601207733154
#   }
#   relative_keypoints {
#     x: 0.6741744875907898
#     y: 0.4177781939506531
#   }
#   relative_keypoints {
#     x: 0.6634859442710876
#     y: 0.48926520347595215
#   }
#   relative_keypoints {
#     x: 0.5296399593353271
#     y: 0.3333844542503357
#   }
#   relative_keypoints {
#     x: 0.7770136594772339
#     y: 0.37418389320373535
#   }
# }
# ]
# [label_id: 0
# score: 0.9537579417228699
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5117563009262085
#     ymin: 0.2017686814069748
#     width: 0.2902751564979553
#     height: 0.3870229721069336
#   }
#   relative_keypoints {
#     x: 0.6129894256591797
#     y: 0.30258119106292725
#   }
#   relative_keypoints {
#     x: 0.7341113686561584
#     y: 0.33121609687805176
#   }
#   relative_keypoints {
#     x: 0.6726130247116089
#     y: 0.41777515411376953
#   }
#   relative_keypoints {
#     x: 0.6592172384262085
#     y: 0.4890114665031433
#   }
#   relative_keypoints {
#     x: 0.5265100598335266
#     y: 0.3095770478248596
#   }
#   relative_keypoints {
#     x: 0.7825674414634705
#     y: 0.36624985933303833
#   }
# }
# ]
# [label_id: 0
# score: 0.9537579417228699
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5117563009262085
#     ymin: 0.2017686814069748
#     width: 0.2902751564979553
#     height: 0.3870229721069336
#   }
#   relative_keypoints {
#     x: 0.6129894256591797
#     y: 0.30258119106292725
#   }
#   relative_keypoints {
#     x: 0.7341113686561584
#     y: 0.33121609687805176
#   }
#   relative_keypoints {
#     x: 0.6726130247116089
#     y: 0.41777515411376953
#   }
#   relative_keypoints {
#     x: 0.6592172384262085
#     y: 0.4890114665031433
#   }
#   relative_keypoints {
#     x: 0.5265100598335266
#     y: 0.3095770478248596
#   }
#   relative_keypoints {
#     x: 0.7825674414634705
#     y: 0.36624985933303833
#   }
# }
# ]
# [label_id: 0
# score: 0.9245904684066772
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5181618928909302
#     ymin: 0.20972342789173126
#     width: 0.2826126217842102
#     height: 0.3768080472946167
#   }
#   relative_keypoints {
#     x: 0.609188973903656
#     y: 0.31211012601852417
#   }
#   relative_keypoints {
#     x: 0.7302375435829163
#     y: 0.3236364722251892
#   }
#   relative_keypoints {
#     x: 0.6726388931274414
#     y: 0.41070234775543213
#   }
#   relative_keypoints {
#     x: 0.6663570404052734
#     y: 0.48479533195495605
#   }
#   relative_keypoints {
#     x: 0.5302879810333252
#     y: 0.3366127610206604
#   }
#   relative_keypoints {
#     x: 0.7844144105911255
#     y: 0.35839027166366577
#   }
# }
# ]
# [label_id: 0
# score: 0.9215951561927795
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5215128660202026
#     ymin: 0.1926211267709732
#     width: 0.2963257431983948
#     height: 0.39509016275405884
#   }
#   relative_keypoints {
#     x: 0.6158576011657715
#     y: 0.3012228012084961
#   }
#   relative_keypoints {
#     x: 0.7417411208152771
#     y: 0.32539504766464233
#   }
#   relative_keypoints {
#     x: 0.6751282811164856
#     y: 0.41809719800949097
#   }
#   relative_keypoints {
#     x: 0.6659794449806213
#     y: 0.49000436067581177
#   }
#   relative_keypoints {
#     x: 0.5365752577781677
#     y: 0.308052122592926
#   }
#   relative_keypoints {
#     x: 0.7996305227279663
#     y: 0.35527288913726807
#   }
# }
# ]
# [label_id: 0
# score: 0.9215951561927795
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5215128660202026
#     ymin: 0.1926211267709732
#     width: 0.2963257431983948
#     height: 0.39509016275405884
#   }
#   relative_keypoints {
#     x: 0.6158576011657715
#     y: 0.3012228012084961
#   }
#   relative_keypoints {
#     x: 0.7417411208152771
#     y: 0.32539504766464233
#   }
#   relative_keypoints {
#     x: 0.6751282811164856
#     y: 0.41809719800949097
#   }
#   relative_keypoints {
#     x: 0.6659794449806213
#     y: 0.49000436067581177
#   }
#   relative_keypoints {
#     x: 0.5365752577781677
#     y: 0.308052122592926
#   }
#   relative_keypoints {
#     x: 0.7996305227279663
#     y: 0.35527288913726807
#   }
# }
# ]
# [label_id: 0
# score: 0.9108262062072754
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5191603899002075
#     ymin: 0.19819001853466034
#     width: 0.2963027358055115
#     height: 0.3950587511062622
#   }
#   relative_keypoints {
#     x: 0.613189160823822
#     y: 0.3068687915802002
#   }
#   relative_keypoints {
#     x: 0.7377313375473022
#     y: 0.328530490398407
#   }
#   relative_keypoints {
#     x: 0.6715519428253174
#     y: 0.4207985997200012
#   }
#   relative_keypoints {
#     x: 0.6633352041244507
#     y: 0.4936996102333069
#   }
#   relative_keypoints {
#     x: 0.536533772945404
#     y: 0.3170931339263916
#   }
#   relative_keypoints {
#     x: 0.7966659665107727
#     y: 0.360035240650177
#   }
# }
# ]
# [label_id: 0
# score: 0.9108262062072754
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5191603899002075
#     ymin: 0.19819001853466034
#     width: 0.2963027358055115
#     height: 0.3950587511062622
#   }
#   relative_keypoints {
#     x: 0.613189160823822
#     y: 0.3068687915802002
#   }
#   relative_keypoints {
#     x: 0.7377313375473022
#     y: 0.328530490398407
#   }
#   relative_keypoints {
#     x: 0.6715519428253174
#     y: 0.4207985997200012
#   }
#   relative_keypoints {
#     x: 0.6633352041244507
#     y: 0.4936996102333069
#   }
#   relative_keypoints {
#     x: 0.536533772945404
#     y: 0.3170931339263916
#   }
#   relative_keypoints {
#     x: 0.7966659665107727
#     y: 0.360035240650177
#   }
# }
# ]
# [label_id: 0
# score: 0.9432742595672607
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5175659656524658
#     ymin: 0.19847412407398224
#     width: 0.29522955417633057
#     height: 0.3936276435852051
#   }
#   relative_keypoints {
#     x: 0.6208077073097229
#     y: 0.3046112656593323
#   }
#   relative_keypoints {
#     x: 0.743932843208313
#     y: 0.32992756366729736
#   }
#   relative_keypoints {
#     x: 0.6840465068817139
#     y: 0.4214550852775574
#   }
#   relative_keypoints {
#     x: 0.6723366379737854
#     y: 0.4933319687843323
#   }
#   relative_keypoints {
#     x: 0.533412754535675
#     y: 0.3144068121910095
#   }
#   relative_keypoints {
#     x: 0.7907047271728516
#     y: 0.3625006675720215
#   }
# }
# ]
# [label_id: 0
# score: 0.9432742595672607
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5175659656524658
#     ymin: 0.19847412407398224
#     width: 0.29522955417633057
#     height: 0.3936276435852051
#   }
#   relative_keypoints {
#     x: 0.6208077073097229
#     y: 0.3046112656593323
#   }
#   relative_keypoints {
#     x: 0.743932843208313
#     y: 0.32992756366729736
#   }
#   relative_keypoints {
#     x: 0.6840465068817139
#     y: 0.4214550852775574
#   }
#   relative_keypoints {
#     x: 0.6723366379737854
#     y: 0.4933319687843323
#   }
#   relative_keypoints {
#     x: 0.533412754535675
#     y: 0.3144068121910095
#   }
#   relative_keypoints {
#     x: 0.7907047271728516
#     y: 0.3625006675720215
#   }
# }
# ]
# [label_id: 0
# score: 0.911888062953949
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5159697532653809
#     ymin: 0.19089050590991974
#     width: 0.3019534945487976
#     height: 0.4025918245315552
#   }
#   relative_keypoints {
#     x: 0.6149311065673828
#     y: 0.29774385690689087
#   }
#   relative_keypoints {
#     x: 0.7432095408439636
#     y: 0.31946730613708496
#   }
#   relative_keypoints {
#     x: 0.6789053678512573
#     y: 0.41142725944519043
#   }
#   relative_keypoints {
#     x: 0.669718325138092
#     y: 0.4893726706504822
#   }
#   relative_keypoints {
#     x: 0.5313697457313538
#     y: 0.31403762102127075
#   }
#   relative_keypoints {
#     x: 0.7986378073692322
#     y: 0.3554418683052063
#   }
# }
# ]
# [label_id: 0
# score: 0.911888062953949
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5159697532653809
#     ymin: 0.19089050590991974
#     width: 0.3019534945487976
#     height: 0.4025918245315552
#   }
#   relative_keypoints {
#     x: 0.6149311065673828
#     y: 0.29774385690689087
#   }
#   relative_keypoints {
#     x: 0.7432095408439636
#     y: 0.31946730613708496
#   }
#   relative_keypoints {
#     x: 0.6789053678512573
#     y: 0.41142725944519043
#   }
#   relative_keypoints {
#     x: 0.669718325138092
#     y: 0.4893726706504822
#   }
#   relative_keypoints {
#     x: 0.5313697457313538
#     y: 0.31403762102127075
#   }
#   relative_keypoints {
#     x: 0.7986378073692322
#     y: 0.3554418683052063
#   }
# }
# ]
# [label_id: 0
# score: 0.8947325348854065
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5242590308189392
#     ymin: 0.19459255039691925
#     width: 0.2986668348312378
#     height: 0.3982105255126953
#   }
#   relative_keypoints {
#     x: 0.6227865815162659
#     y: 0.29649919271469116
#   }
#   relative_keypoints {
#     x: 0.7508470416069031
#     y: 0.3366650938987732
#   }
#   relative_keypoints {
#     x: 0.6782357692718506
#     y: 0.42173856496810913
#   }
#   relative_keypoints {
#     x: 0.663749098777771
#     y: 0.4954793453216553
#   }
#   relative_keypoints {
#     x: 0.5386802554130554
#     y: 0.2961495518684387
#   }
#   relative_keypoints {
#     x: 0.8051289916038513
#     y: 0.37530457973480225
#   }
# }
# ]
# [label_id: 0
# score: 0.9324092268943787
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5193429589271545
#     ymin: 0.19592075049877167
#     width: 0.2988026738166809
#     height: 0.39839184284210205
#   }
#   relative_keypoints {
#     x: 0.6191532611846924
#     y: 0.30624961853027344
#   }
#   relative_keypoints {
#     x: 0.7461278438568115
#     y: 0.3262280225753784
#   }
#   relative_keypoints {
#     x: 0.6850875020027161
#     y: 0.4215015172958374
#   }
#   relative_keypoints {
#     x: 0.675778865814209
#     y: 0.4948863387107849
#   }
#   relative_keypoints {
#     x: 0.533183217048645
#     y: 0.318481981754303
#   }
#   relative_keypoints {
#     x: 0.798080325126648
#     y: 0.3559926152229309
#   }
# }
# ]
# [label_id: 0
# score: 0.9324092268943787
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5193429589271545
#     ymin: 0.19592075049877167
#     width: 0.2988026738166809
#     height: 0.39839184284210205
#   }
#   relative_keypoints {
#     x: 0.6191532611846924
#     y: 0.30624961853027344
#   }
#   relative_keypoints {
#     x: 0.7461278438568115
#     y: 0.3262280225753784
#   }
#   relative_keypoints {
#     x: 0.6850875020027161
#     y: 0.4215015172958374
#   }
#   relative_keypoints {
#     x: 0.675778865814209
#     y: 0.4948863387107849
#   }
#   relative_keypoints {
#     x: 0.533183217048645
#     y: 0.318481981754303
#   }
#   relative_keypoints {
#     x: 0.798080325126648
#     y: 0.3559926152229309
#   }
# }
# ]
# [label_id: 0
# score: 0.9356386661529541
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5218120813369751
#     ymin: 0.20052461326122284
#     width: 0.2923993468284607
#     height: 0.3898548483848572
#   }
#   relative_keypoints {
#     x: 0.6225473284721375
#     y: 0.30306941270828247
#   }
#   relative_keypoints {
#     x: 0.746645450592041
#     y: 0.33160942792892456
#   }
#   relative_keypoints {
#     x: 0.6843379735946655
#     y: 0.41856008768081665
#   }
#   relative_keypoints {
#     x: 0.6715104579925537
#     y: 0.49114328622817993
#   }
#   relative_keypoints {
#     x: 0.5348981022834778
#     y: 0.3111347556114197
#   }
#   relative_keypoints {
#     x: 0.7951153516769409
#     y: 0.36666566133499146
#   }
# }
# ]
# [label_id: 0
# score: 0.9356386661529541
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5218120813369751
#     ymin: 0.20052461326122284
#     width: 0.2923993468284607
#     height: 0.3898548483848572
#   }
#   relative_keypoints {
#     x: 0.6225473284721375
#     y: 0.30306941270828247
#   }
#   relative_keypoints {
#     x: 0.746645450592041
#     y: 0.33160942792892456
#   }
#   relative_keypoints {
#     x: 0.6843379735946655
#     y: 0.41856008768081665
#   }
#   relative_keypoints {
#     x: 0.6715104579925537
#     y: 0.49114328622817993
#   }
#   relative_keypoints {
#     x: 0.5348981022834778
#     y: 0.3111347556114197
#   }
#   relative_keypoints {
#     x: 0.7951153516769409
#     y: 0.36666566133499146
#   }
# }
# ]
# [label_id: 0
# score: 0.9289693236351013
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5162525773048401
#     ymin: 0.1975952833890915
#     width: 0.29982006549835205
#     height: 0.39974796772003174
#   }
#   relative_keypoints {
#     x: 0.6192368268966675
#     y: 0.30795425176620483
#   }
#   relative_keypoints {
#     x: 0.7446067929267883
#     y: 0.32582539319992065
#   }
#   relative_keypoints {
#     x: 0.6854821443557739
#     y: 0.42066138982772827
#   }
#   relative_keypoints {
#     x: 0.675967276096344
#     y: 0.495242178440094
#   }
#   relative_keypoints {
#     x: 0.5320723056793213
#     y: 0.3226774334907532
#   }
#   relative_keypoints {
#     x: 0.7947039604187012
#     y: 0.3572855591773987
#   }
# }
# ]
# [label_id: 0
# score: 0.9289693236351013
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5162525773048401
#     ymin: 0.1975952833890915
#     width: 0.29982006549835205
#     height: 0.39974796772003174
#   }
#   relative_keypoints {
#     x: 0.6192368268966675
#     y: 0.30795425176620483
#   }
#   relative_keypoints {
#     x: 0.7446067929267883
#     y: 0.32582539319992065
#   }
#   relative_keypoints {
#     x: 0.6854821443557739
#     y: 0.42066138982772827
#   }
#   relative_keypoints {
#     x: 0.675967276096344
#     y: 0.495242178440094
#   }
#   relative_keypoints {
#     x: 0.5320723056793213
#     y: 0.3226774334907532
#   }
#   relative_keypoints {
#     x: 0.7947039604187012
#     y: 0.3572855591773987
#   }
# }
# ]
# [label_id: 0
# score: 0.937949001789093
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5205180644989014
#     ymin: 0.2023128718137741
#     width: 0.2926618456840515
#     height: 0.3902049660682678
#   }
#   relative_keypoints {
#     x: 0.6238341927528381
#     y: 0.30647146701812744
#   }
#   relative_keypoints {
#     x: 0.745931088924408
#     y: 0.3293501138687134
#   }
#   relative_keypoints {
#     x: 0.6880789399147034
#     y: 0.41810208559036255
#   }
#   relative_keypoints {
#     x: 0.6761406660079956
#     y: 0.49104171991348267
#   }
#   relative_keypoints {
#     x: 0.5351793766021729
#     y: 0.3190285563468933
#   }
#   relative_keypoints {
#     x: 0.7921651005744934
#     y: 0.36379289627075195
#   }
# }
# ]
# [label_id: 0
# score: 0.937949001789093
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5205180644989014
#     ymin: 0.2023128718137741
#     width: 0.2926618456840515
#     height: 0.3902049660682678
#   }
#   relative_keypoints {
#     x: 0.6238341927528381
#     y: 0.30647146701812744
#   }
#   relative_keypoints {
#     x: 0.745931088924408
#     y: 0.3293501138687134
#   }
#   relative_keypoints {
#     x: 0.6880789399147034
#     y: 0.41810208559036255
#   }
#   relative_keypoints {
#     x: 0.6761406660079956
#     y: 0.49104171991348267
#   }
#   relative_keypoints {
#     x: 0.5351793766021729
#     y: 0.3190285563468933
#   }
#   relative_keypoints {
#     x: 0.7921651005744934
#     y: 0.36379289627075195
#   }
# }
# ]
# [label_id: 0
# score: 0.936992883682251
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5227351188659668
#     ymin: 0.19985277950763702
#     width: 0.29460209608078003
#     height: 0.3927921652793884
#   }
#   relative_keypoints {
#     x: 0.622504711151123
#     y: 0.30706727504730225
#   }
#   relative_keypoints {
#     x: 0.7456886172294617
#     y: 0.3289337158203125
#   }
#   relative_keypoints {
#     x: 0.684618353843689
#     y: 0.4203898310661316
#   }
#   relative_keypoints {
#     x: 0.6743780374526978
#     y: 0.49220532178878784
#   }
#   relative_keypoints {
#     x: 0.5384162664413452
#     y: 0.3178061246871948
#   }
#   relative_keypoints {
#     x: 0.7970542907714844
#     y: 0.3610183596611023
#   }
# }
# ]
# [label_id: 0
# score: 0.936992883682251
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5227351188659668
#     ymin: 0.19985277950763702
#     width: 0.29460209608078003
#     height: 0.3927921652793884
#   }
#   relative_keypoints {
#     x: 0.622504711151123
#     y: 0.30706727504730225
#   }
#   relative_keypoints {
#     x: 0.7456886172294617
#     y: 0.3289337158203125
#   }
#   relative_keypoints {
#     x: 0.684618353843689
#     y: 0.4203898310661316
#   }
#   relative_keypoints {
#     x: 0.6743780374526978
#     y: 0.49220532178878784
#   }
#   relative_keypoints {
#     x: 0.5384162664413452
#     y: 0.3178061246871948
#   }
#   relative_keypoints {
#     x: 0.7970542907714844
#     y: 0.3610183596611023
#   }
# }
# ]
# [label_id: 0
# score: 0.9398202300071716
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5243368744850159
#     ymin: 0.1996425837278366
#     width: 0.29591530561447144
#     height: 0.394542932510376
#   }
#   relative_keypoints {
#     x: 0.6278478503227234
#     y: 0.3052976727485657
#   }
#   relative_keypoints {
#     x: 0.751398503780365
#     y: 0.3341897130012512
#   }
#   relative_keypoints {
#     x: 0.6899606585502625
#     y: 0.42386406660079956
#   }
#   relative_keypoints {
#     x: 0.6767935156822205
#     y: 0.4953693747520447
#   }
#   relative_keypoints {
#     x: 0.5386807322502136
#     y: 0.3104356527328491
#   }
#   relative_keypoints {
#     x: 0.7989176511764526
#     y: 0.3665957450866699
#   }
# }
# ]
# [label_id: 0
# score: 0.9398202300071716
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5243368744850159
#     ymin: 0.1996425837278366
#     width: 0.29591530561447144
#     height: 0.394542932510376
#   }
#   relative_keypoints {
#     x: 0.6278478503227234
#     y: 0.3052976727485657
#   }
#   relative_keypoints {
#     x: 0.751398503780365
#     y: 0.3341897130012512
#   }
#   relative_keypoints {
#     x: 0.6899606585502625
#     y: 0.42386406660079956
#   }
#   relative_keypoints {
#     x: 0.6767935156822205
#     y: 0.4953693747520447
#   }
#   relative_keypoints {
#     x: 0.5386807322502136
#     y: 0.3104356527328491
#   }
#   relative_keypoints {
#     x: 0.7989176511764526
#     y: 0.3665957450866699
#   }
# }
# ]
# [label_id: 0
# score: 0.9308379292488098
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5179843902587891
#     ymin: 0.19069065153598785
#     width: 0.30106693506240845
#     height: 0.4014114737510681
#   }
#   relative_keypoints {
#     x: 0.6163139939308167
#     y: 0.2995806932449341
#   }
#   relative_keypoints {
#     x: 0.7417917847633362
#     y: 0.3245578408241272
#   }
#   relative_keypoints {
#     x: 0.6749765872955322
#     y: 0.418016254901886
#   }
#   relative_keypoints {
#     x: 0.6649211049079895
#     y: 0.4915282726287842
#   }
#   relative_keypoints {
#     x: 0.5358421802520752
#     y: 0.3065667748451233
#   }
#   relative_keypoints {
#     x: 0.7985871434211731
#     y: 0.356988787651062
#   }
# }
# ]
# [label_id: 0
# score: 0.9499875903129578
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5242928266525269
#     ymin: 0.20545299351215363
#     width: 0.28666484355926514
#     height: 0.3822106122970581
#   }
#   relative_keypoints {
#     x: 0.6215078234672546
#     y: 0.30412060022354126
#   }
#   relative_keypoints {
#     x: 0.7423622012138367
#     y: 0.3307272791862488
#   }
#   relative_keypoints {
#     x: 0.6802803874015808
#     y: 0.4144793152809143
#   }
#   relative_keypoints {
#     x: 0.6682077646255493
#     y: 0.4865115284919739
#   }
#   relative_keypoints {
#     x: 0.5380128026008606
#     y: 0.3146510720252991
#   }
#   relative_keypoints {
#     x: 0.7930660247802734
#     y: 0.3686597943305969
#   }
# }
# ]
# [label_id: 0
# score: 0.9499875903129578
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5242928266525269
#     ymin: 0.20545299351215363
#     width: 0.28666484355926514
#     height: 0.3822106122970581
#   }
#   relative_keypoints {
#     x: 0.6215078234672546
#     y: 0.30412060022354126
#   }
#   relative_keypoints {
#     x: 0.7423622012138367
#     y: 0.3307272791862488
#   }
#   relative_keypoints {
#     x: 0.6802803874015808
#     y: 0.4144793152809143
#   }
#   relative_keypoints {
#     x: 0.6682077646255493
#     y: 0.4865115284919739
#   }
#   relative_keypoints {
#     x: 0.5380128026008606
#     y: 0.3146510720252991
#   }
#   relative_keypoints {
#     x: 0.7930660247802734
#     y: 0.3686597943305969
#   }
# }
# ]
# [label_id: 0
# score: 0.9404314160346985
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5229882001876831
#     ymin: 0.1986108273267746
#     width: 0.29543793201446533
#     height: 0.393906831741333
#   }
#   relative_keypoints {
#     x: 0.6265522241592407
#     y: 0.30064302682876587
#   }
#   relative_keypoints {
#     x: 0.7489452958106995
#     y: 0.3299708366394043
#   }
#   relative_keypoints {
#     x: 0.6869773864746094
#     y: 0.4172940254211426
#   }
#   relative_keypoints {
#     x: 0.6735901832580566
#     y: 0.4908071756362915
#   }
#   relative_keypoints {
#     x: 0.5388543009757996
#     y: 0.30974966287612915
#   }
#   relative_keypoints {
#     x: 0.796576976776123
#     y: 0.3673779368400574
#   }
# }
# ]
# [label_id: 0
# score: 0.9404314160346985
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5229882001876831
#     ymin: 0.1986108273267746
#     width: 0.29543793201446533
#     height: 0.393906831741333
#   }
#   relative_keypoints {
#     x: 0.6265522241592407
#     y: 0.30064302682876587
#   }
#   relative_keypoints {
#     x: 0.7489452958106995
#     y: 0.3299708366394043
#   }
#   relative_keypoints {
#     x: 0.6869773864746094
#     y: 0.4172940254211426
#   }
#   relative_keypoints {
#     x: 0.6735901832580566
#     y: 0.4908071756362915
#   }
#   relative_keypoints {
#     x: 0.5388543009757996
#     y: 0.30974966287612915
#   }
#   relative_keypoints {
#     x: 0.796576976776123
#     y: 0.3673779368400574
#   }
# }
# ]
# [label_id: 0
# score: 0.9414782524108887
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.523917555809021
#     ymin: 0.2059069126844406
#     width: 0.28950637578964233
#     height: 0.38599860668182373
#   }
#   relative_keypoints {
#     x: 0.6285412311553955
#     y: 0.3045858144760132
#   }
#   relative_keypoints {
#     x: 0.7481400370597839
#     y: 0.33672767877578735
#   }
#   relative_keypoints {
#     x: 0.6876766085624695
#     y: 0.4194188714027405
#   }
#   relative_keypoints {
#     x: 0.6722524762153625
#     y: 0.4914171099662781
#   }
#   relative_keypoints {
#     x: 0.5390474796295166
#     y: 0.31104332208633423
#   }
#   relative_keypoints {
#     x: 0.7921109199523926
#     y: 0.37579983472824097
#   }
# }
# ...
#     x: 0.6636673212051392
#     y: 0.49420589208602905
#   }
#   relative_keypoints {
#     x: 0.5317645072937012
#     y: 0.30703920125961304
#   }
#   relative_keypoints {
#     x: 0.7911056280136108
#     y: 0.3713095784187317
#   }
# }
# ]
# [label_id: 0
# score: 0.9299654364585876
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5132370591163635
#     ymin: 0.20368032157421112
#     width: 0.2926459312438965
#     height: 0.3901839256286621
#   }
#   relative_keypoints {
#     x: 0.6156669855117798
#     y: 0.3041742444038391
#   }
#   relative_keypoints {
#     x: 0.7357782125473022
#     y: 0.3333371877670288
#   }
#   relative_keypoints {
#     x: 0.6745598316192627
#     y: 0.4195171594619751
#   }
#   relative_keypoints {
#     x: 0.661450207233429
#     y: 0.4929589629173279
#   }
#   relative_keypoints {
#     x: 0.5307514071464539
#     y: 0.31360816955566406
#   }
#   relative_keypoints {
#     x: 0.783921480178833
#     y: 0.37010443210601807
#   }
# }
# ]
# [label_id: 0
# score: 0.9471752047538757
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5151090621948242
#     ymin: 0.20162729918956757
#     width: 0.2942742109298706
#     height: 0.39235568046569824
#   }
#   relative_keypoints {
#     x: 0.6147207021713257
#     y: 0.30822044610977173
#   }
#   relative_keypoints {
#     x: 0.7362074255943298
#     y: 0.3359321355819702
#   }
#   relative_keypoints {
#     x: 0.6727049350738525
#     y: 0.42808908224105835
#   }
#   relative_keypoints {
#     x: 0.661054253578186
#     y: 0.4971640706062317
#   }
#   relative_keypoints {
#     x: 0.5325940251350403
#     y: 0.31036484241485596
#   }
#   relative_keypoints {
#     x: 0.7884804606437683
#     y: 0.36429548263549805
#   }
# }
# ]
# [label_id: 0
# score: 0.9471752047538757
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5151090621948242
#     ymin: 0.20162729918956757
#     width: 0.2942742109298706
#     height: 0.39235568046569824
#   }
#   relative_keypoints {
#     x: 0.6147207021713257
#     y: 0.30822044610977173
#   }
#   relative_keypoints {
#     x: 0.7362074255943298
#     y: 0.3359321355819702
#   }
#   relative_keypoints {
#     x: 0.6727049350738525
#     y: 0.42808908224105835
#   }
#   relative_keypoints {
#     x: 0.661054253578186
#     y: 0.4971640706062317
#   }
#   relative_keypoints {
#     x: 0.5325940251350403
#     y: 0.31036484241485596
#   }
#   relative_keypoints {
#     x: 0.7884804606437683
#     y: 0.36429548263549805
#   }
# }
# ]
# [label_id: 0
# score: 0.9345054626464844
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5134345889091492
#     ymin: 0.20118336379528046
#     width: 0.2967720031738281
#     height: 0.3956853151321411
#   }
#   relative_keypoints {
#     x: 0.6140134930610657
#     y: 0.30264657735824585
#   }
#   relative_keypoints {
#     x: 0.7379342913627625
#     y: 0.3325294852256775
#   }
#   relative_keypoints {
#     x: 0.6725122928619385
#     y: 0.41991764307022095
#   }
#   relative_keypoints {
#     x: 0.659656822681427
#     y: 0.49510741233825684
#   }
#   relative_keypoints {
#     x: 0.5298323631286621
#     y: 0.3116838335990906
#   }
#   relative_keypoints {
#     x: 0.790097713470459
#     y: 0.3705422282218933
#   }
# }
# ]
# [label_id: 0
# score: 0.9345054626464844
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5134345889091492
#     ymin: 0.20118336379528046
#     width: 0.2967720031738281
#     height: 0.3956853151321411
#   }
#   relative_keypoints {
#     x: 0.6140134930610657
#     y: 0.30264657735824585
#   }
#   relative_keypoints {
#     x: 0.7379342913627625
#     y: 0.3325294852256775
#   }
#   relative_keypoints {
#     x: 0.6725122928619385
#     y: 0.41991764307022095
#   }
#   relative_keypoints {
#     x: 0.659656822681427
#     y: 0.49510741233825684
#   }
#   relative_keypoints {
#     x: 0.5298323631286621
#     y: 0.3116838335990906
#   }
#   relative_keypoints {
#     x: 0.790097713470459
#     y: 0.3705422282218933
#   }
# }
# ]
# [label_id: 0
# score: 0.9339463710784912
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5170847773551941
#     ymin: 0.19833578169345856
#     width: 0.2966917157173157
#     height: 0.39557701349258423
#   }
#   relative_keypoints {
#     x: 0.6172235012054443
#     y: 0.3109171390533447
#   }
#   relative_keypoints {
#     x: 0.7400198578834534
#     y: 0.3305092453956604
#   }
#   relative_keypoints {
#     x: 0.6801831722259521
#     y: 0.42778080701828003
#   }
#   relative_keypoints {
#     x: 0.6703724265098572
#     y: 0.49742406606674194
#   }
#   relative_keypoints {
#     x: 0.533668041229248
#     y: 0.3166096806526184
#   }
#   relative_keypoints {
#     x: 0.791715681552887
#     y: 0.3545383810997009
#   }
# }
# ]
# [label_id: 0
# score: 0.9339463710784912
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5170847773551941
#     ymin: 0.19833578169345856
#     width: 0.2966917157173157
#     height: 0.39557701349258423
#   }
#   relative_keypoints {
#     x: 0.6172235012054443
#     y: 0.3109171390533447
#   }
#   relative_keypoints {
#     x: 0.7400198578834534
#     y: 0.3305092453956604
#   }
#   relative_keypoints {
#     x: 0.6801831722259521
#     y: 0.42778080701828003
#   }
#   relative_keypoints {
#     x: 0.6703724265098572
#     y: 0.49742406606674194
#   }
#   relative_keypoints {
#     x: 0.533668041229248
#     y: 0.3166096806526184
#   }
#   relative_keypoints {
#     x: 0.791715681552887
#     y: 0.3545383810997009
#   }
# }
# ]
# [label_id: 0
# score: 0.938072681427002
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5201581120491028
#     ymin: 0.1984124630689621
#     width: 0.2953752875328064
#     height: 0.393823504447937
#   }
#   relative_keypoints {
#     x: 0.6178907752037048
#     y: 0.30500584840774536
#   }
#   relative_keypoints {
#     x: 0.7403361201286316
#     y: 0.33055049180984497
#   }
#   relative_keypoints {
#     x: 0.6755790710449219
#     y: 0.4220436215400696
#   }
#   relative_keypoints {
#     x: 0.664099931716919
#     y: 0.49335354566574097
#   }
#   relative_keypoints {
#     x: 0.537083625793457
#     y: 0.3095819354057312
#   }
#   relative_keypoints {
#     x: 0.7951222658157349
#     y: 0.36191684007644653
#   }
# }
# ]
# [label_id: 0
# score: 0.9208729863166809
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5321022272109985
#     ymin: 0.2171603888273239
#     width: 0.28258341550827026
#     height: 0.3767669200897217
#   }
#   relative_keypoints {
#     x: 0.623822808265686
#     y: 0.31388646364212036
#   }
#   relative_keypoints {
#     x: 0.7440480589866638
#     y: 0.33404552936553955
#   }
#   relative_keypoints {
#     x: 0.6817200779914856
#     y: 0.4152725338935852
#   }
#   relative_keypoints {
#     x: 0.6715131998062134
#     y: 0.48964232206344604
#   }
#   relative_keypoints {
#     x: 0.5439388751983643
#     y: 0.3316439390182495
#   }
#   relative_keypoints {
#     x: 0.7989206910133362
#     y: 0.3755353093147278
#   }
# }
# ]
# [label_id: 0
# score: 0.9208729863166809
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5321022272109985
#     ymin: 0.2171603888273239
#     width: 0.28258341550827026
#     height: 0.3767669200897217
#   }
#   relative_keypoints {
#     x: 0.623822808265686
#     y: 0.31388646364212036
#   }
#   relative_keypoints {
#     x: 0.7440480589866638
#     y: 0.33404552936553955
#   }
#   relative_keypoints {
#     x: 0.6817200779914856
#     y: 0.4152725338935852
#   }
#   relative_keypoints {
#     x: 0.6715131998062134
#     y: 0.48964232206344604
#   }
#   relative_keypoints {
#     x: 0.5439388751983643
#     y: 0.3316439390182495
#   }
#   relative_keypoints {
#     x: 0.7989206910133362
#     y: 0.3755353093147278
#   }
# }
# ]
# [label_id: 0
# score: 0.9081052541732788
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5269976854324341
#     ymin: 0.20747347176074982
#     width: 0.29109489917755127
#     height: 0.3881150484085083
#   }
#   relative_keypoints {
#     x: 0.6330415606498718
#     y: 0.31119292974472046
#   }
#   relative_keypoints {
#     x: 0.7522664070129395
#     y: 0.338348388671875
#   }
#   relative_keypoints {
#     x: 0.6942582130432129
#     y: 0.425261914730072
#   }
#   relative_keypoints {
#     x: 0.6790476441383362
#     y: 0.4971405863761902
#   }
#   relative_keypoints {
#     x: 0.5422327518463135
#     y: 0.31597429513931274
#   }
#   relative_keypoints {
#     x: 0.794847846031189
#     y: 0.37215787172317505
#   }
# }
# ]
# [label_id: 0
# score: 0.9081052541732788
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5269976854324341
#     ymin: 0.20747347176074982
#     width: 0.29109489917755127
#     height: 0.3881150484085083
#   }
#   relative_keypoints {
#     x: 0.6330415606498718
#     y: 0.31119292974472046
#   }
#   relative_keypoints {
#     x: 0.7522664070129395
#     y: 0.338348388671875
#   }
#   relative_keypoints {
#     x: 0.6942582130432129
#     y: 0.425261914730072
#   }
#   relative_keypoints {
#     x: 0.6790476441383362
#     y: 0.4971405863761902
#   }
#   relative_keypoints {
#     x: 0.5422327518463135
#     y: 0.31597429513931274
#   }
#   relative_keypoints {
#     x: 0.794847846031189
#     y: 0.37215787172317505
#   }
# }
# ]
# [label_id: 0
# score: 0.9447236061096191
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5227838158607483
#     ymin: 0.20364801585674286
#     width: 0.28982633352279663
#     height: 0.38642418384552
#   }
#   relative_keypoints {
#     x: 0.6353362202644348
#     y: 0.3090319037437439
#   }
#   relative_keypoints {
#     x: 0.7511395812034607
#     y: 0.3385797142982483
#   }
#   relative_keypoints {
#     x: 0.6977438926696777
#     y: 0.4293261766433716
#   }
#   relative_keypoints {
#     x: 0.6798977255821228
#     y: 0.4963763952255249
#   }
#   relative_keypoints {
#     x: 0.5392134189605713
#     y: 0.30400675535202026
#   }
#   relative_keypoints {
#     x: 0.7859230041503906
#     y: 0.3651854395866394
#   }
# }
# ]
# [label_id: 0
# score: 0.9447236061096191
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5227838158607483
#     ymin: 0.20364801585674286
#     width: 0.28982633352279663
#     height: 0.38642418384552
#   }
#   relative_keypoints {
#     x: 0.6353362202644348
#     y: 0.3090319037437439
#   }
#   relative_keypoints {
#     x: 0.7511395812034607
#     y: 0.3385797142982483
#   }
#   relative_keypoints {
#     x: 0.6977438926696777
#     y: 0.4293261766433716
#   }
#   relative_keypoints {
#     x: 0.6798977255821228
#     y: 0.4963763952255249
#   }
#   relative_keypoints {
#     x: 0.5392134189605713
#     y: 0.30400675535202026
#   }
#   relative_keypoints {
#     x: 0.7859230041503906
#     y: 0.3651854395866394
#   }
# }
# ]
# [label_id: 0
# score: 0.946824312210083
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5295950174331665
#     ymin: 0.20300431549549103
#     width: 0.28716737031936646
#     height: 0.3828805685043335
#   }
#   relative_keypoints {
#     x: 0.6375748515129089
#     y: 0.302775502204895
#   }
#   relative_keypoints {
#     x: 0.7541858553886414
#     y: 0.33966177701950073
#   }
#   relative_keypoints {
#     x: 0.6945871710777283
#     y: 0.4242165684700012
#   }
#   relative_keypoints {
#     x: 0.6750757694244385
#     y: 0.49139779806137085
#   }
#   relative_keypoints {
#     x: 0.5440874695777893
#     y: 0.29454511404037476
#   }
#   relative_keypoints {
#     x: 0.7930939793586731
#     y: 0.3718806505203247
#   }
# }
# ]
# [label_id: 0
# score: 0.946824312210083
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5295950174331665
#     ymin: 0.20300431549549103
#     width: 0.28716737031936646
#     height: 0.3828805685043335
#   }
#   relative_keypoints {
#     x: 0.6375748515129089
#     y: 0.302775502204895
#   }
#   relative_keypoints {
#     x: 0.7541858553886414
#     y: 0.33966177701950073
#   }
#   relative_keypoints {
#     x: 0.6945871710777283
#     y: 0.4242165684700012
#   }
#   relative_keypoints {
#     x: 0.6750757694244385
#     y: 0.49139779806137085
#   }
#   relative_keypoints {
#     x: 0.5440874695777893
#     y: 0.29454511404037476
#   }
#   relative_keypoints {
#     x: 0.7930939793586731
#     y: 0.3718806505203247
#   }
# }
# ]
# [label_id: 0
# score: 0.9290061593055725
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5233892202377319
#     ymin: 0.20204128324985504
#     width: 0.29152971506118774
#     height: 0.3886955976486206
#   }
#   relative_keypoints {
#     x: 0.626778244972229
#     y: 0.2950540781021118
#   }
#   relative_keypoints {
#     x: 0.7460225820541382
#     y: 0.3328942656517029
#   }
#   relative_keypoints {
#     x: 0.6800756454467773
#     y: 0.4111637473106384
#   }
#   relative_keypoints {
#     x: 0.6626749038696289
#     y: 0.4872570037841797
#   }
#   relative_keypoints {
#     x: 0.5404595136642456
#     y: 0.30153727531433105
#   }
#   relative_keypoints {
#     x: 0.7931928038597107
#     y: 0.3802524209022522
#   }
# }
# ]
# [label_id: 0
# score: 0.9294859766960144
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5245245695114136
#     ymin: 0.20290391147136688
#     width: 0.29145705699920654
#     height: 0.3885977268218994
#   }
#   relative_keypoints {
#     x: 0.6298011541366577
#     y: 0.3060781955718994
#   }
#   relative_keypoints {
#     x: 0.7492023706436157
#     y: 0.33222734928131104
#   }
#   relative_keypoints {
#     x: 0.6907994747161865
#     y: 0.41971367597579956
#   }
#   relative_keypoints {
#     x: 0.6763286590576172
#     y: 0.4919869303703308
#   }
#   relative_keypoints {
#     x: 0.5404239892959595
#     y: 0.31267720460891724
#   }
#   relative_keypoints {
#     x: 0.7928193807601929
#     y: 0.36689847707748413
#   }
# }
# ]
# [label_id: 0
# score: 0.9294859766960144
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5245245695114136
#     ymin: 0.20290391147136688
#     width: 0.29145705699920654
#     height: 0.3885977268218994
#   }
#   relative_keypoints {
#     x: 0.6298011541366577
#     y: 0.3060781955718994
#   }
#   relative_keypoints {
#     x: 0.7492023706436157
#     y: 0.33222734928131104
#   }
#   relative_keypoints {
#     x: 0.6907994747161865
#     y: 0.41971367597579956
#   }
#   relative_keypoints {
#     x: 0.6763286590576172
#     y: 0.4919869303703308
#   }
#   relative_keypoints {
#     x: 0.5404239892959595
#     y: 0.31267720460891724
#   }
#   relative_keypoints {
#     x: 0.7928193807601929
#     y: 0.36689847707748413
#   }
# }
# ]
# [label_id: 0
# score: 0.9482513666152954
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5272510051727295
#     ymin: 0.2057427316904068
#     width: 0.29003262519836426
#     height: 0.38669949769973755
#   }
#   relative_keypoints {
#     x: 0.6306201219558716
#     y: 0.3085785508155823
#   }
#   relative_keypoints {
#     x: 0.7504413723945618
#     y: 0.3327353596687317
#   }
#   relative_keypoints {
#     x: 0.6929982900619507
#     y: 0.4213153123855591
#   }
#   relative_keypoints {
#     x: 0.6804783940315247
#     y: 0.4927445650100708
#   }
#   relative_keypoints {
#     x: 0.542339563369751
#     y: 0.31956958770751953
#   }
#   relative_keypoints {
#     x: 0.7953827977180481
#     y: 0.3674010634422302
#   }
# }
# ]
# [label_id: 0
# score: 0.9482513666152954
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5272510051727295
#     ymin: 0.2057427316904068
#     width: 0.29003262519836426
#     height: 0.38669949769973755
#   }
#   relative_keypoints {
#     x: 0.6306201219558716
#     y: 0.3085785508155823
#   }
#   relative_keypoints {
#     x: 0.7504413723945618
#     y: 0.3327353596687317
#   }
#   relative_keypoints {
#     x: 0.6929982900619507
#     y: 0.4213153123855591
#   }
#   relative_keypoints {
#     x: 0.6804783940315247
#     y: 0.4927445650100708
#   }
#   relative_keypoints {
#     x: 0.542339563369751
#     y: 0.31956958770751953
#   }
#   relative_keypoints {
#     x: 0.7953827977180481
#     y: 0.3674010634422302
#   }
# }
# ]
# [label_id: 0
# score: 0.8606054782867432
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.5369442105293274
#     ymin: 0.1982411891222
#     width: 0.29167789220809937
#     height: 0.388891339302063
#   }
#   relative_keypoints {
#     x: 0.6390814185142517
#     y: 0.29458552598953247
#   }
#   relative_keypoints {
#     x: 0.7591730356216431
#     y: 0.32820653915405273
#   }
#   relative_keypoints {
#     x: 0.6952816843986511
#     y: 0.4099727272987366
#   }
#   relative_keypoints {
#     x: 0.6794533133506775
#     y: 0.48672693967819214
#   }
#   relative_keypoints {
#     x: 0.5525500774383545
#     y: 0.3022952675819397
#   }
#   relative_keypoints {
#     x: 0.8051254749298096
#     y: 0.37081801891326904
#   }
# }
# ]
