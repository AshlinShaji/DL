# %%
#Open_CV
import cv2

# %%
img=cv2.imread('baby1.jpg')
img
# Out:
# array([[[ 13,  13,  29],
#         [ 13,  13,  29],
#         [ 13,  13,  29],
#         ...,
#         [ 23,  11,   1],
#         [ 23,  11,   1],
#         [ 23,  11,   1]],
#
#        [[ 13,  13,  29],
#         [ 13,  13,  29],
#         [ 13,  13,  29],
#         ...,
#         [ 23,  11,   1],
#         [ 23,  11,   1],
#         [ 23,  11,   1]],
#
#        [[ 13,  13,  29],
#         [ 13,  13,  29],
#         [ 13,  13,  31],
#         ...,
#         [ 23,  11,   1],
#         [ 23,  11,   1],
#         [ 23,  11,   1]],
#
#        ...,
#
#        [[205, 220, 199],
#         [205, 220, 199],
#         [205, 220, 199],
#         ...,
#         [211, 226, 212],
#         [211, 227, 210],
#         [212, 227, 206]],
#
#        [[207, 220, 198],
#         [207, 220, 198],
#         [207, 220, 198],
#         ...,
#         [213, 226, 212],
#         [213, 226, 210],
#         [212, 226, 208]],
#
#        [[206, 219, 197],
#         [206, 219, 197],
#         [206, 219, 197],
# ...

# %%
img.shape
# Out:
# (350, 465, 3)

# %%
#To show thw image
cv2.imshow('Baby_image',img)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
img1=cv2.imread('baby2.jpg')
img1
# Out:
# array([[[212, 212, 212],
#         [212, 212, 212],
#         [212, 212, 212],
#         ...,
#         [218, 218, 218],
#         [218, 218, 218],
#         [218, 218, 218]],
#
#        [[212, 212, 212],
#         [212, 212, 212],
#         [212, 212, 212],
#         ...,
#         [218, 218, 218],
#         [218, 218, 218],
#         [218, 218, 218]],
#
#        [[213, 211, 211],
#         [213, 211, 211],
#         [213, 211, 211],
#         ...,
#         [217, 217, 217],
#         [217, 217, 217],
#         [217, 217, 217]],
#
#        ...,
#
#        [[144, 135, 178],
#         [143, 134, 177],
#         [141, 134, 179],
#         ...,
#         [233, 233, 233],
#         [233, 233, 233],
#         [233, 233, 233]],
#
#        [[145, 136, 179],
#         [144, 135, 178],
#         [141, 134, 179],
#         ...,
#         [233, 233, 233],
#         [233, 233, 233],
#         [233, 233, 233]],
#
#        [[145, 136, 179],
#         [144, 135, 178],
#         [141, 134, 179],
# ...

# %%
img1.shape
# Out:
# (1000, 800, 3)

# %%
cv2.imshow('Baby_image',img1)
cv2.waitKey(3000)
cv2.destroyAllWindows()

# %%
#To convert image to grey_scale
img_gray=cv2.imread('baby1.jpg',cv2.IMREAD_GRAYSCALE)
img_gray
# Out:
# array([[ 18,  18,  18, ...,   9,   9,   9],
#        [ 18,  18,  18, ...,   9,   9,   9],
#        [ 18,  18,  18, ...,   9,   9,   9],
#        ...,
#        [212, 212, 212, ..., 220, 220, 219],
#        [212, 212, 212, ..., 220, 220, 219],
#        [211, 211, 211, ..., 219, 219, 218]], shape=(350, 465), dtype=uint8)

# %%
img_gray.shape
# Out:
# (350, 465)

# %%
cv2.imshow('Baby_image',img_gray)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
#to save gryscale image

cv2.imwrite('baby_greyscale.jpg',img_gray)
# Out:
# True

# %%
img_grey1=cv2.imread('baby2.jpg',cv2.IMREAD_GRAYSCALE)
img_grey1
# Out:
# array([[212, 212, 212, ..., 218, 218, 218],
#        [212, 212, 212, ..., 218, 218, 218],
#        [211, 211, 211, ..., 217, 217, 217],
#        ...,
#        [149, 148, 148, ..., 233, 233, 233],
#        [150, 149, 148, ..., 233, 233, 233],
#        [150, 149, 148, ..., 233, 233, 233]],
#       shape=(1000, 800), dtype=uint8)

# %%
img_grey1.shape
# Out:
# (1000, 800)

# %%
cv2.imread('Baby_image',img_grey1)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
cv2.imwrite('baby_grey1.jpg',img_grey1)
# Out:
# True

# %%
#image convert to binary image
#we cannot convert image directly to binary so we first convrt image to greyscale then binary
#threshold 2 variable
thres,bin_img=cv2.threshold(img_gray,125,255,cv2.THRESH_BINARY)
cv2.imshow('Binary_image',bin_img)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
thres
# Out:
# 125.0

# %%
cv2.imwrite('baby1_bin_img.jpg',bin_img)
# Out:
# True

# %%
#image2 baby2
thres1,bin_img1=cv2.threshold(img_grey1,125,255,cv2.THRESH_BINARY)
cv2.imshow('Binary image',bin_img1)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
cv2.imwrite('baby2_bin_img.jpg',bin_img1)
# Out:
# True

# %%
#thresh_otsu -- used to define thresh value automatically

thres,bin_img=cv2.threshold(img_gray,125,255,cv2.THRESH_OTSU)
cv2.imshow('Binary_image',bin_img)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
thres
# Out:
# 96.0

# %%
#image display is used matplotlib

img1=cv2.imread('baby1.jpg')
img1
# Out:
# array([[[ 13,  13,  29],
#         [ 13,  13,  29],
#         [ 13,  13,  29],
#         ...,
#         [ 23,  11,   1],
#         [ 23,  11,   1],
#         [ 23,  11,   1]],
#
#        [[ 13,  13,  29],
#         [ 13,  13,  29],
#         [ 13,  13,  29],
#         ...,
#         [ 23,  11,   1],
#         [ 23,  11,   1],
#         [ 23,  11,   1]],
#
#        [[ 13,  13,  29],
#         [ 13,  13,  29],
#         [ 13,  13,  31],
#         ...,
#         [ 23,  11,   1],
#         [ 23,  11,   1],
#         [ 23,  11,   1]],
#
#        ...,
#
#        [[205, 220, 199],
#         [205, 220, 199],
#         [205, 220, 199],
#         ...,
#         [211, 226, 212],
#         [211, 227, 210],
#         [212, 227, 206]],
#
#        [[207, 220, 198],
#         [207, 220, 198],
#         [207, 220, 198],
#         ...,
#         [213, 226, 212],
#         [213, 226, 210],
#         [212, 226, 208]],
#
#        [[206, 219, 197],
#         [206, 219, 197],
#         [206, 219, 197],
# ...

# %%
import matplotlib.pyplot as plt
plt.imshow(img1)

# %%
#to convert bgr image to rgb
conv_img=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
plt.imshow(conv_img)

# %%
#Bounding Box
#Rectangle
#left top , Right Bottom
#(180,100)  (350,275)
cv2.rectangle(conv_img,pt1=(180,100),pt2=(350,275),color=(255,0,0),thickness=3)
plt.imshow(conv_img)

# %%
img2=cv2.imread('baby2.jpg')
img
# Out:
# array([[[ 13,  13,  29],
#         [ 13,  13,  29],
#         [ 13,  13,  29],
#         ...,
#         [ 23,  11,   1],
#         [ 23,  11,   1],
#         [ 23,  11,   1]],
#
#        [[ 13,  13,  29],
#         [ 13,  13,  29],
#         [ 13,  13,  29],
#         ...,
#         [ 23,  11,   1],
#         [ 23,  11,   1],
#         [ 23,  11,   1]],
#
#        [[ 13,  13,  29],
#         [ 13,  13,  29],
#         [ 13,  13,  31],
#         ...,
#         [ 23,  11,   1],
#         [ 23,  11,   1],
#         [ 23,  11,   1]],
#
#        ...,
#
#        [[205, 220, 199],
#         [205, 220, 199],
#         [205, 220, 199],
#         ...,
#         [211, 226, 212],
#         [211, 227, 210],
#         [212, 227, 206]],
#
#        [[207, 220, 198],
#         [207, 220, 198],
#         [207, 220, 198],
#         ...,
#         [213, 226, 212],
#         [213, 226, 210],
#         [212, 226, 208]],
#
#        [[206, 219, 197],
#         [206, 219, 197],
#         [206, 219, 197],
# ...

# %%
import matplotlib.pyplot as plt
plt.imshow(img2)

# %%
conv_img1=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)
plt.imshow(conv_img1)

# %%
#Bounding image
#(200,50)  (600,450)
cv2.rectangle(conv_img1,pt1=(200,50),pt2=(600,450),color=(255,0,0),thickness=3)
plt.imshow(conv_img1)

# %%
img33=cv2.imread('baby3.jpg')
conv_img33=cv2.cvtColor(img3,cv2.COLOR_BGR2RGB)
plt.imshow(conv_img33)

# %%
#circle
#center
#radius
cv2.circle(conv_img33,center=(400,300),radius=150,color=(0,0,255),thickness=3)
plt.imshow(conv_img33)

# %%
img4=cv2.imread('baby4.jpeg')
conv_img4=cv2.cvtColor(img4,cv2.COLOR_BGR2RGB)
plt.imshow(conv_img4)

# %%
#Add text to image
cv2.putText(conv_img4,text='Baby',org=(1500,1500),fontFace=cv2.FONT_HERSHEY_SIMPLEX,fontScale=10,color=(255,0,0),thickness=10)
plt.imshow(conv_img4)

# %%
# image read
# imshow

# grey scale
#
# binary Image

# matplotlib display

# bgr===>rgb

# rectangle ==> ltop, rbottom
# circle ==> center, radius
# text ==> org, fontface, fontsize, color, thickness
