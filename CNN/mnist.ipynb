# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPool2D 
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
#reshape

x_train=x_train.reshape(60000,28,28,1)
x_test=x_test.reshape(10000,28,28,1)

# %%
x_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
#normalization
x_train=x_train/255
x_test=x_test/255

# %%
#Defining model
model=Sequential()
#Convolutional layer
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
#adding pooling layer
model.add(MaxPool2D(2,2))
#Add fully connected layer
model.add(Flatten())
model.add(Dense(100,activation='relu'))
#adding output layer
model.add(Dense(10,activation='softmax'))
# Out:
# c:\Users\ashli\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=10,batch_size=1000)
# Out:
# Epoch 1/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 9s 138ms/step - accuracy: 0.8467 - loss: 0.5858
# Epoch 2/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.9446 - loss: 0.1923
# Epoch 3/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 7s 113ms/step - accuracy: 0.9639 - loss: 0.1281
# Epoch 4/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 8s 136ms/step - accuracy: 0.9732 - loss: 0.0959
# Epoch 5/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9793 - loss: 0.0751
# Epoch 6/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.9824 - loss: 0.0632
# Epoch 7/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.9853 - loss: 0.0537
# Epoch 8/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 8s 131ms/step - accuracy: 0.9871 - loss: 0.0477
# Epoch 9/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 8s 132ms/step - accuracy: 0.9886 - loss: 0.0415
# Epoch 10/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 8s 137ms/step - accuracy: 0.9895 - loss: 0.0383

# %%
model.evaluate(x_test,y_test,batch_size=1000)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9849 - loss: 0.0465
# [0.04651186987757683, 0.9848999977111816]

# %%
import numpy as np
from skimage.io import imread
from skimage.transform import resize
img='C:/Users/ashli/Documents/DL/CNN/three.png'
img1=imread(img)
img2=resize(img1,(1,28,28,1))
img3=img2/255
pred=model.predict(img3)

pred1=np.argmax(pred)
pred1
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# np.int64(1)
