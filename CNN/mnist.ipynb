# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPool2D 
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
# Out:
# c:\Users\ashli\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
#reshape

x_train=x_train.reshape(60000,28,28,1)
x_test=x_test.reshape(10000,28,28,1)

# %%
x_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
#normalization
x_train=x_train/255
x_test=x_test/255

# %%
#Defining model
model=Sequential()
#Convolutional layer
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
#adding pooling layer
model.add(MaxPool2D(2,2))
#Add fully connected layer
model.add(Flatten())
model.add(Dense(100,activation='relu'))
#adding output layer
model.add(Dense(10,activation='softmax'))
# Out:
# c:\Users\ashli\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=10,batch_size=1000)
# Out:
# Epoch 1/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.8560 - loss: 0.6199
# Epoch 2/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - accuracy: 0.9459 - loss: 0.1878
# Epoch 3/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 8s 139ms/step - accuracy: 0.9664 - loss: 0.1196
# Epoch 4/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 9s 147ms/step - accuracy: 0.9755 - loss: 0.0884
# Epoch 5/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 10s 159ms/step - accuracy: 0.9804 - loss: 0.0719
# Epoch 6/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 9s 153ms/step - accuracy: 0.9829 - loss: 0.0612
# Epoch 7/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 9s 143ms/step - accuracy: 0.9852 - loss: 0.0524
# Epoch 8/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 9s 142ms/step - accuracy: 0.9871 - loss: 0.0461
# Epoch 9/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 8s 136ms/step - accuracy: 0.9881 - loss: 0.0417
# Epoch 10/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 8s 138ms/step - accuracy: 0.9892 - loss: 0.0382

# %%
model.evaluate(x_test,y_test,batch_size=1000)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9832 - loss: 0.0485
# [0.04847148433327675, 0.9832000136375427]

# %%
import numpy as np
from skimage.io import imread
from skimage.transform import resize
img='C:/Users/ashli/Documents/DL/CNN/three.png'
img1=imread(img)
img2=resize(img1,(1,28,28,1))
img3=img2/255
pred=model.predict(img3)

pred1=np.argmax(pred)
pred1
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# np.int64(1)
