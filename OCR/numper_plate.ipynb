# %%
import cv2
import re
import pytesseract

# %%
img=cv2.imread('number_plate.jpg')
img
# Out:
# array([[[137, 117, 160],
#         [138, 117, 162],
#         [133, 112, 157],
#         ...,
#         [140, 120, 165],
#         [140, 120, 165],
#         [142, 122, 167]],
#
#        [[138, 115, 160],
#         [135, 114, 159],
#         [135, 113, 161],
#         ...,
#         [138, 119, 168],
#         [138, 119, 168],
#         [138, 119, 168]],
#
#        [[137, 114, 159],
#         [134, 113, 158],
#         [135, 114, 159],
#         ...,
#         [140, 121, 170],
#         [136, 117, 166],
#         [139, 120, 169]],
#
#        ...,
#
#        [[  2,  10,  57],
#         [  4,  12,  59],
#         [  2,  12,  59],
#         ...,
#         [  3,  12,  69],
#         [  2,  11,  68],
#         [  2,  13,  70]],
#
#        [[  3,  12,  56],
#         [  3,  12,  56],
#         [  4,  13,  57],
#         ...,
#         [  1,  14,  66],
#         [  1,  15,  64],
#         [  2,  16,  65]],
#
#        [[  3,  12,  56],
#         [  4,  13,  57],
#         [  3,  12,  56],
#         ...,
#         [  1,  14,  66],
#         [  1,  15,  64],
#         [  2,  16,  65]]], shape=(570, 870, 3), dtype=uint8)

# %%
cv2.imshow('Number_plate', img)
cv2.waitKey(5000)  
cv2.destroyAllWindows()

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Users\ashli\Documents\tesseract ocr\tesseract.exe'

# %%
text=pytesseract.image_to_string(img)
print(text)
